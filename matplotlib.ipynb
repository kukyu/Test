# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'MicroSoft YaHei'

figure, axes = plt.subplots(2, 2)  # 创建一个包含一个axes的figure
axes[0, 0].plot([1, 2, 3, 4], [1, 4, 2, 3], color='blue', linewidth=2, linestyle='-.',
                marker='*', markersize=10)  # 绘制图像
axes[0, 1].bar([1, 2, 3, 4], [1, 4, 2, 3], color=(0.2, 1.0, 1.0), width=0.8)  # 绘制图像
axes[1, 0].barh(["深圳", "广州", "北京", "上海"], [1, 4, 2, 3], height=0.5, color="#0aff00")
axes[1, 1].stackplot([1, 2, 3, 4], [1, 4, 2, 3], color=(0.4, 0.2, 0.1, 0.1))

# %%
import matplotlib.pyplot as plt
plt.pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"])
plt.show()

# %%
import matplotlib.pyplot as plt 
figure, axes = plt.subplots(2, 2)
axes[0, 0].pie([1, 4, 2, 3], labels = ["深圳", "广州", "北京", "上海"])
axes[0, 1].pie([1, 4, 2, 3], labels = ["深圳", "广州", "北京", "上海"], autopct = '%.2f%%', 
               explode=[0, 0, 0.2, 0])
axes[1, 0].pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"], autopct='%.2f%%', 
        labeldistance=1.2, pctdistance=0.6)  # 绘制图像
axes[1, 1].pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"], autopct='%.2f%%', 
         pctdistance=0.6, wedgeprops={'width': 0.5, 'linewidth': 2, 'edgecolor': 'w'})  # 绘制图像
plt.show()

# %%
import matplotlib.pyplot as plt
import random
# figure, axes = plt.subplots(2, 2)
data_x = [random.randint(1, 100) for _ in range(100)]
data_y = [random.randint(1, 100) for _ in range(100)]
plt.scatter(data_x, data_y)
plt.show()

# %%
import numpy as np
N = 30
x = np.random.rand(N)
y = np.random.rand(N)
color = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2

plt.scatter(x, y, s = area, c=color, alpha=0.2)
plt.show()

# %%
import numpy as np
N = 30
x = np.random.rand(N)
y = np.random.rand(N)
color = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2

plt.scatter(x, y, s = area, c=color, alpha=0.2, marker="*", edgecolors='blue')
plt.show()

# %%
plt.rcParams['font.sans-serif'] = 'Kaiti'
# 还可以设置的中为字体有SimSun（宋体），SimHei（黑体），Kaiti（楷体）等
x = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']
y = [123, 145, 152, 182, 147, 138, 189, 201, 203, 211, 201, 182]
plt.plot(x, y, linestyle='-.', marker='p', markersize=5)  # 绘制图像
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.figure(figsize=(8, 6))
x = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']
y = [123, 145, 152, 182, 147, 138, 189, 201, 203, 211, 201, 182]
plt.title("销售趋势图", fontdict={'family':'Kaiti', 'color': 'k', 'size': 15})
plt.plot(x, y, linestyle='-.', marker='o', markersize=10)  # 绘制图像
plt.xlabel("月份", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size': 12}, labelpad=10)
plt.ylabel("销售额（万元）", fontdict={'family':'Microsoft YaHei', 'color': 'b', 'size': 12}, labelpad=10)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.figure(figsize=(8, 6))
x = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']
y1 = [123, 145, 152, 182, 147, 138, 189, 201, 203, 211, 201, 182]
y2 = [102, 121, 138, 154, 171, 178, 199, 231, 228, 202, 231, 271]

plt.title("销售趋势图", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size': 15})
plt.plot(x, y1, linestyle='-.', marker='o', markersize=10, color='r', label='华东')  # 绘制图像
plt.plot(x, y2, linestyle='-', marker='o', markersize=10, color='y', label='华中')  # 绘制图像
plt.xlabel("月份", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size': 12}, labelpad=10)
plt.ylabel("销售额（万元）", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size': 12}, labelpad=10)
plt.legend(loc='best', fontsize=12) # best:matplotlib根据图表自动选择最优位置
# 添加数据标签
# plt.text(a, b, b, va='bottom', fontdict={"size":14})：在坐标 (a, b) 处添加标签，标签内容为 b，va='bottom' 表示标签在点的下方，fontdict={"size":14} 设置标签字体大小为 14。
for a, b, c in zip(x, y1, y2):
    plt.text(a, b, b, va='top', fontdict={"size":12})
    plt.text(a, c, c, va='bottom', fontdict={"size":12})


plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.figure(figsize=(8, 6))
x = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']
y1 = [123, 145, 152, 182, 147, 138, 189, 201, 203, 211, 201, 182]
y2 = [102, 121, 138, 154, 171, 178, 199, 231, 228, 202, 231, 271]

plt.title("销售趋势图", fontdict={
          'family': 'Microsoft YaHei', 'color': 'k', 'size': 15}, loc='left')
plt.plot(x, y1, linestyle='-.', marker='o',
         markersize=10, color='r', label='华东')  # 绘制图像
plt.plot(x, y2, linestyle='-', marker='o',
         markersize=10, color='y', label='华中')  # 绘制图像
plt.xlabel("月份", fontdict={'family': 'Microsoft YaHei',
           'color': 'k', 'size': 12}, labelpad=10)
plt.ylabel("销售额（万元）", fontdict={
           'family': 'Microsoft YaHei', 'color': 'k', 'size': 12}, labelpad=10)
plt.legend(loc='best', fontsize=12)  # best:matplotlib根据图表自动选择最优位置
# 设置坐标轴范围
plt.ylim(50, 300)
# # 添加网格线
plt.grid(axis='y', linestyle='--', linewidth=1, color='grey')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use(['ggplot'])
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.figure(figsize=(8, 6))
x = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']
y1 = [123, 145, 152, 182, 147, 138, 189, 201, 203, 211, 201, 182]
y2 = [102, 121, 138, 154, 171, 178, 199, 231, 228, 202, 231, 271]

plt.title("销售趋势图", fontdict={'family':'Microsoft YaHei', 'size': 15}, loc='left')
plt.plot(x, y1, linestyle='-.', marker='o', markersize=10, color='r', label='华东')  # 绘制图像
plt.plot(x, y2, linestyle='-', marker='o', markersize=10, color='y', label='华中')  # 绘制图像
plt.xlabel("月份", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size': 12}, labelpad=5)
plt.ylabel("销售额（万元）", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size': 12}, labelpad=10)
plt.legend(loc='best', fontsize=12) # best:matplotlib根据图表自动选择最优位置
# 设置坐标轴范围
plt.ylim(50, 300)
# 添加网格线
plt.grid( axis='y', linestyle='--', linewidth=1, color='grey')
plt.show()

# %%
import matplotlib.pyplot as plt  

data = [1, 2, 3, 4, 5]  
plt.plot(data)  
plt.xlabel('X axis label')  
plt.ylabel('Y axis label')  
plt.title('My Data Visualization')  
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'

x = ["深圳", "广州", "北京", "上海"]
y = [1, 3, 2, 5]

plt.subplot(2, 2, 1)
plt.bar(x, y)

plt.subplot(2, 2, 2)
plt.pie(y, labels=x)

plt.subplot(2, 2, 3)
plt.plot(x, y)

plt.subplot(2, 2, 4)
plt.barh(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt

x = ["深圳", "广州", "北京", "上海"]
y = [1, 3, 2, 5]

fig, axs = plt.subplots(2, 2)
axs[0][0].bar(x, y)
axs[0][1].pie(y, labels=x)
axs[1][0].plot(x, y)
axs[1][1].barh(x, y)
plt.show()

# %%
# 我们可以通过.add_gridspec()将整个画布划分成不均匀的区域；
# spec = fig.add_gridspec(nrows=2, ncols=2, width_ratios=[1, 3], height_ratios=[1,2]) 表示将整个画布裁剪为2行2列的区域，width_ratios=[1, 3]表示横向将两列的宽度按照1:3进行裁剪，同理height_ratios=[1,2]表示纵向按照1:2进行裁剪
import matplotlib.pyplot as plt

x = ["深圳", "广州", "北京", "上海"]
y = [1, 3, 2, 5]

fig = plt.figure(figsize=(10, 8))
spec = fig.add_gridspec(nrows=2, ncols=2, width_ratios=[1, 3], height_ratios=[1,2])
ax = fig.add_subplot(spec[0, 0])
ax.bar(x, y)

ax = fig.add_subplot(spec[0, 1])
ax.plot(x, y)

ax = fig.add_subplot(spec[1, 0])
ax.pie(y, labels=x)

ax = fig.add_subplot(spec[1, 1])
ax.barh(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt

x = ["深圳", "广州", "北京", "上海"]
y = [1, 3, 2, 5]

fig = plt.figure(figsize=(10, 8))
spec = fig.add_gridspec(nrows=2, ncols=2, width_ratios=[1, 3], height_ratios=[1,2])
ax = fig.add_subplot(spec[0, 0])
ax.bar(x, y)

ax = fig.add_subplot(spec[0, 1])
ax.plot(x, y)

# 第二行整块区域显示条形图
ax = fig.add_subplot(spec[1, :])
ax.barh(x, y)

# 调整各区域之间的距离
plt.subplots_adjust(hspace=0.3, wspace=0.2)
plt.show()

# %% [markdown]
# 添加元素
# ax子图同样可以通过set_title、set_xlable等方法添加子图标题，坐标轴标题等；
#
# 如果需要添加大标题可以通过fig.suptitle()来完成；

# %%
import matplotlib.pyplot as plt

x = ["深圳", "广州", "北京", "上海"]
y = [1, 3, 2, 5]

fig = plt.figure(figsize=(10, 8))
fig.suptitle("不均匀子图示例", size=20, fontdict={'family':'Microsoft YaHei', 'color': 'r'})
spec = fig.add_gridspec(nrows=2, ncols=2, width_ratios=[1, 3], height_ratios=[1,2])
ax = fig.add_subplot(spec[0, 0])
ax.bar(x, y)
ax.set_title("柱形图", loc='left', fontdict={'family':'Microsoft YaHei', 'color': 'k'})
ax.set_ylabel("销售额", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size':12})

ax = fig.add_subplot(spec[0, 1])
ax.plot(x, y)
ax.set_title("折线图", loc='left', fontdict={'family':'Microsoft YaHei', 'color': 'k'})
ax.set_ylabel("销售额", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size':12})

# 第二行整块区域显示条形图
ax = fig.add_subplot(spec[1, :])
ax.barh(x, y)
ax.set_title("条形图", loc='center', fontdict={'family':'Microsoft YaHei', 'color': 'k'})
ax.set_xlabel("销售额", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size':12})

# 调整各区域之间的距离
plt.subplots_adjust(hspace=0.3, wspace=0.2)
plt.show()

# %% [markdown]
# ### 双Y轴
# 当我们多个系列的数据值量级差别太大时，依赖同一个坐标轴来展示通常效果很差，比如需要将销售额和利润同时展示出来；
#
# 这时候我们可以通过plt.twix()添加次坐标轴；

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.figure(figsize=(8, 6))
x = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']
y1 = [123, 145, 152, 182, 147, 138, 189, 201, 203, 211, 201, 182]
y2 = [2, 11, 18, 14, 11, 18, 19, 21, 28, 22, 21, 21]

# 绘制柱形图
plt.title("销售趋势图", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size': 15}, loc='left')
plt.bar(x, y1, color='b', alpha=.5, label='销售额')  # 绘制图像
plt.ylabel("销售额（万元）", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size': 12}, labelpad=10)
plt.ylim(100, 250)

# 添加次坐标轴
plt.twinx()
plt.plot(x, y2, linestyle='-', marker='o', markersize=10, color='r', label='利润')  # 绘制图像
plt.ylabel("利润（万元）", fontdict={'family':'Microsoft YaHei', 'color': 'k', 'size': 12}, labelpad=10)
plt.show()

# %% [markdown]
# 添加阴影

# %%
import matplotlib.patheffects as path_effects

plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.figure(figsize=(8, 6))
x = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']
y = [123, 145, 152, 182, 147, 138, 189, 201, 203, 211, 201, 182]
plt.plot(x, y, linewidth=5, color='blue',
         path_effects=[path_effects.SimpleLineShadow(),
                       path_effects.Normal()])
plt.show()

# %% [markdown]
# ### 添加标记plt.annotate()
# 如果我们想给图表某部分内容添加一些注释，我们可以通过`plt.annotate()`进行添加，其中几个主要参数：
#
# xy：需要我们传入数组，如xy=(1,2)，用于定位要标记的位置；
#
# xycoords：设置xy是通过何种方式去进行定位，比如data表示使用坐标轴刻度值去进行定位；
#
# xytext：提示文本 要展示的位置；
#
# textcoords：同xycoords，设置xytext通过何种何种方式去进行定位

# %%
import matplotlib.patheffects as path_effects
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'


x = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']
y = [123, 145, 152, 182, 147, 138, 189, 201, 203, 211, 201, 182]

plt.figure(figsize=(8, 6))

plt.plot(x, y, linestyle='-', marker='o', markersize=10, color='r', label='利润')  # 绘制图像

plt.annotate("提示", xy=('4月', 182), xycoords='data', xytext=("3月", 200), textcoords='data',
            arrowprops=dict(facecolor='blue', shrink=0.15),)

plt.show()

# %% [markdown]
# ### colormap 色表
# Matplotlib中内置很多配色方法，可以通过代码matplotlib.cm.get_cmap使用；
#
# 其实Matplotlib中的配色方案我们还可以轻松应用到其他第三方模块中；
#
# 支持的配色方案可以点击
#
# ` https://matplotlib.org/2.0.2/examples/color/colormaps_reference.html `
#
# 进行查看

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 30
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2

plt.figure(figsize=(8, 6))
plt.scatter(x, y,
            # 图形大小
            s=area,
            # 颜色
            c=colors,
            # 透明度
            alpha=0.6,
            cmap='magma'
            )
plt.show()

# %%
import matplotlib.pyplot as plt

# 假设有两个产品，每个产品有四个季度的销售数据
quarters = ['Q1', 'Q2', 'Q3', 'Q4']
sales_data = [[100, 120, 90, 110], [150, 130, 160, 140], [100, 120, 90, 110], [150, 130, 160, 140]]

# 创建一个包含 2x2 子图的图形
fig, axs = plt.subplots(2, 2)

# 使用循环遍历每个子图
# axs.flat 是一个 NumPy 扁平化（flattened）数组，它是由子图对象构成的一维数组。
for i, ax in enumerate(axs.flat):
    # 在当前子图中绘制柱形图
    ax.bar(quarters, sales_data[i])
    
    # 设置标题、x轴标签和y轴标签
    ax.set_title(f'Product {i+1}')
    ax.set_xlabel('Quarters')
    ax.set_ylabel('Sales')
# 调整各区域之间的距离
plt.subplots_adjust(hspace=0.8, wspace=0.5)
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 假设有两个产品，每个产品有四个季度的销售数据
quarters = ['Q1', 'Q2', 'Q3', 'Q4']
sales_data = [[100, 120, 90, 110], [150, 130, 160, 140], [100, 120, 90, 110], [150, 130, 160, 140]]

fig, axs = plt.subplots(2, 2)  
for i, ax in enumerate(axs.flat):  
    ax.bar(quarters, sales_data[i])  
    ax.set_title(f'Product {i+1}')  
for ax in axs[:, 0]:  
    ax.set_ylabel('Sales')  
for ax in axs[-1, :]:  
    ax.set_xlabel('Quarters')
# 调整各区域之间的距离
plt.subplots_adjust(hspace=0.5, wspace=0.3)
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 假设有一些月份和对应的温度数据
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
temperatures = [5, 10, 15, 20, 25, 30, 35, 30, 25, 20, 15, 10]

# 创建一个包含 4x1 子图的图形
# fig, axs = plt.subplots(4, 1)

fig, axs = plt.subplots(4, 1)  
for ax in axs:
    ax.set_ylim(-10, 40)
    ax.plot(months, temperatures)

# 调整各区域之间的距离
plt.subplots_adjust(hspace=0.8, wspace=0.5)
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 假设有一些随机数据
data = np.random.randn(100)

# 创建一个包含 3x2 子图的图形
fig, axs = plt.subplots(3, 2)

# 在第五个位置（第三行第一列）上绘制箱线图
axs[2, 0].boxplot(data)
axs[2, 0].set_title('Boxplot')

# 在同一个子图上叠加绘制直方图
axs[2, 0].hist(data, bins=20, alpha=0.5, color='orange')
axs[2, 0].set_title('Boxplot with Histogram Overlay')

# 显示图形
plt.show()
